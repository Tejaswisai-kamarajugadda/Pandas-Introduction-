# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejaswisai-kamarajugadda/Pandas-Introduction-/blob/main/pandas_introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Credit_Card_Applications.csv')

# %%
dataset
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# 0    100  1213      0
# 1    160     1      0
# 2    280     1      0
# 3      0     1      1
# 4     60   159      1
# ..   ...   ...    ...
# 685    0     1      1
# 686    0    45      0
# 687  100     1      1
# 688  120    12      1
# 689  560     1      1
#
# [690 rows x 16 columns]

# %%
dataset.info
# Out:
# <bound method DataFrame.info of      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# 0    100  1213      0
# 1    160     1      0
# 2    280     1      0
# 3      0     1      1
# 4     60   159      1
# ..   ...   ...    ...
# 685    0     1      1
# 686    0    45      0
# 687  100     1      1
# 688  120    12      1
# 689  560     1      1
#
# [690 rows x 16 columns]>

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  690 non-null    int64
#  1   A1          690 non-null    int64
#  2   A2          690 non-null    float64
#  3   A3          690 non-null    float64
#  4   A4          690 non-null    int64
#  5   A5          690 non-null    int64
#  6   A6          690 non-null    int64
#  7   A7          690 non-null    float64
#  8   A8          690 non-null    int64
#  9   A9          690 non-null    int64
#  10  A10         690 non-null    int64
#  11  A11         690 non-null    int64
#  12  A12         690 non-null    int64
#  13  A13         690 non-null    int64
#  14  A14         690 non-null    int64
#  15  Class       690 non-null    int64
# dtypes: float64(3), int64(13)
# memory usage: 86.4 KB

# %%
dataset.loc[[0,1,2],['A2','A5','A7']]
# Out:
#       A2  A5     A7
# 0  22.08   4  1.585
# 1  22.67   8  0.165
# 2  29.58   4  1.250

# %%
dataset.loc[1,'A2']
# Out:
# 22.67

# %%
dataset.iloc[[0,1,5],[11,2,1]]
# Out:
#    A11     A2  A1
# 0    1  22.08   1
# 1    0  22.67   0
# 5    0  15.83   0

# %%
dataset.loc[1,'A2']=23

# %%
dataset.loc[1,'A2']
# Out:
# 22.67

# %%
dataset.columns
# Out:
# Index(['CustomerID', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9',
#        'A10', 'A11', 'A12', 'A13', 'A14', 'Class'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#          CustomerID          A1          A2          A3          A4  \
# count  6.900000e+02  690.000000  690.000000  690.000000  690.000000
# mean   1.569047e+07    0.678261   31.568203    4.758725    1.766667
# std    7.150647e+04    0.467482   11.853273    4.978163    0.430063
# min    1.556571e+07    0.000000   13.750000    0.000000    1.000000
# 25%    1.563169e+07    0.000000   22.670000    1.000000    2.000000
# 50%    1.569016e+07    1.000000   28.625000    2.750000    2.000000
# 75%    1.575190e+07    1.000000   37.707500    7.207500    2.000000
# max    1.581544e+07    1.000000   80.250000   28.000000    3.000000
#
#                A5          A6          A7          A8          A9        A10  \
# count  690.000000  690.000000  690.000000  690.000000  690.000000  690.00000
# mean     7.372464    4.692754    2.223406    0.523188    0.427536    2.40000
# std      3.683265    1.992316    3.346513    0.499824    0.495080    4.86294
# min      1.000000    1.000000    0.000000    0.000000    0.000000    0.00000
# 25%      4.000000    4.000000    0.165000    0.000000    0.000000    0.00000
# 50%      8.000000    4.000000    1.000000    1.000000    0.000000    0.00000
# 75%     10.000000    5.000000    2.625000    1.000000    1.000000    3.00000
# max     14.000000    9.000000   28.500000    1.000000    1.000000   67.00000
#
#               A11         A12          A13            A14       Class
# count  690.000000  690.000000   690.000000     690.000000  690.000000
# mean     0.457971    1.928986   184.014493    1018.385507    0.444928
# std      0.498592    0.298813   172.159274    5210.102598    0.497318
# min      0.000000    1.000000     0.000000       1.000000    0.000000
# 25%      0.000000    2.000000    80.000000       1.000000    0.000000
# 50%      0.000000    2.000000   160.000000       6.000000    0.000000
# 75%      1.000000    2.000000   272.000000     396.500000    1.000000
# max      1.000000    3.000000  2000.000000  100001.000000    1.000000

# %%
dataset.loc[0,'A7']
# Out:
# 1.585

# %%
import random
age = []
height = []
weight = []
speed = []
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))
idata = {'Age':age,'Height':height,'weight':weight,'speed':speed}

# %%
idata
# Out:
# {'Age': [96,
#   99,
#   84,
#   78,
#   30,
#   66,
#   1,
#   29,
#   16,
#   22,
#   90,
#   15,
#   25,
#   80,
#   2,
#   96,
#   7,
#   94,
#   85,
#   34,
#   79,
#   7,
#   23,
#   14,
#   99,
#   51,
#   50,
#   71,
#   27,
#   18,
#   42,
#   64,
#   90,
#   62,
#   89,
#   28,
#   89,
#   47,
#   63,
#   19,
#   55,
#   72,
#   11,
#   80,
#   14,
#   25,
#   40,
#   42,
#   84,
#   24,
#   79,
#   47,
#   91,
#   25,
#   65,
#   18,
#   18,
#   43,
#   87,
#   96,
#   89,
#   65,
#   31,
#   82,
#   38,
#   19,
#   11,
#   29,
#   42,
#   96,
#   55,
#   70,
#   18,
#   55,
#   93,
#   70,
#   24,
#   19,
#   31,
#   21,
#   1,
#   87,
#   35,
#   27,
#   26,
#   5,
#   99,
#   1,
#   18,
#   81,
#   56,
#   20,
#   61,
#   81,
#   33,
#   25,
#   8,
#   20,
#   9,
#   30],
#  'Height': [45,
#   21,
#   32,
#   76,
#   33,
#   34,
#   54,
#   50,
#   100,
#   65,
#   42,
#   22,
#   55,
#   97,
#   40,
#   72,
#   30,
#   43,
#   73,
#   29,
#   54,
#   28,
#   70,
#   17,
#   44,
#   53,
#   6,
#   58,
#   74,
#   12,
#   80,
#   43,
#   22,
#   13,
#   42,
#   96,
#   53,
#   57,
#   14,
#   59,
#   46,
#   86,
#   67,
#   7,
#   7,
#   11,
#   58,
#   59,
#   47,
#   39,
#   30,
#   73,
#   6,
#   78,
#   0,
#   47,
#   25,
#   8,
#   52,
#   24,
#   11,
#   11,
#   40,
#   96,
#   76,
#   90,
#   30,
#   46,
#   1,
#   34,
#   81,
#   76,
#   20,
#   30,
#   20,
#   90,
#   51,
#   6,
#   68,
#   62,
#   14,
#   79,
#   26,
#   67,
#   82,
#   75,
#   32,
#   6,
#   74,
#   41,
#   18,
#   25,
#   87,
#   43,
#   11,
#   33,
#   22,
#   71,
#   48,
#   10],
#  'weight': [76,
#   27,
#   64,
#   55,
#   21,
#   4,
#   56,
#   100,
#   23,
#   44,
#   67,
#   70,
#   0,
#   30,
#   77,
#   81,
#   54,
#   11,
#   68,
#   41,
#   37,
#   73,
#   12,
#   67,
#   58,
#   68,
#   88,
#   25,
#   74,
#   40,
#   3,
#   44,
#   91,
#   87,
#   61,
#   64,
#   68,
#   58,
#   57,
#   22,
#   48,
#   32,
#   20,
#   84,
#   100,
#   78,
#   89,
#   32,
#   52,
#   36,
#   47,
#   61,
#   79,
#   92,
#   96,
#   34,
#   63,
#   4,
#   97,
#   20,
#   43,
#   94,
#   39,
#   12,
#   71,
#   36,
#   20,
#   14,
#   52,
#   72,
#   33,
#   5,
#   63,
#   13,
#   92,
#   70,
#   45,
#   17,
#   83,
#   58,
#   6,
#   55,
#   64,
#   46,
#   27,
#   42,
#   8,
#   10,
#   66,
#   56,
#   54,
#   85,
#   52,
#   22,
#   38,
#   29,
#   73,
#   27,
#   3,
#   95],
#  'speed': [93,
#   22,
#   39,
#   99,
#   52,
#   98,
#   36,
#   20,
#   71,
#   95,
#   34,
#   74,
#   35,
#   70,
#   37,
#   86,
#   10,
#   95,
#   2,
#   98,
#   64,
#   30,
#   100,
#   24,
#   66,
#   93,
#   73,
#   66,
#   63,
#   96,
#   28,
#   43,
#   87,
#   50,
#   89,
#   33,
#   10,
#   6,
#   56,
#   83,
#   91,
#   28,
#   47,
#   51,
#   97,
#   67,
#   23,
#   58,
#   61,
#   26,
#   73,
#   94,
#   38,
#   15,
#   81,
#   98,
#   87,
#   48,
#   87,
#   15,
#   95,
#   50,
#   28,
#   90,
#   32,
#   2,
#   71,
#   17,
#   23,
#   58,
#   40,
#   28,
#   14,
#   32,
#   41,
#   66,
#   37,
#   86,
#   0,
#   44,
#   61,
#   14,
#   20,
#   80,
#   88,
#   34,
#   78,
#   50,
#   89,
#   62,
#   38,
#   99,
#   44,
#   73,
#   83,
#   79,
#   22,
#   70,
#   46,
#   12]}

# %%
df1 = pd.DataFrame(idata)

# %%
df1
# Out:
#     Age  Height  weight  speed
# 0    96      45      76     93
# 1    99      21      27     22
# 2    84      32      64     39
# 3    78      76      55     99
# 4    30      33      21     52
# ..  ...     ...     ...    ...
# 95   25      33      29     79
# 96    8      22      73     22
# 97   20      71      27     70
# 98    9      48       3     46
# 99   30      10      95     12
#
# [100 rows x 4 columns]

# %%
df1.head(10)
# Out:
#    Age  Height  weight  speed
# 0   96      45      76     93
# 1   99      21      27     22
# 2   84      32      64     39
# 3   78      76      55     99
# 4   30      33      21     52
# 5   66      34       4     98
# 6    1      54      56     36
# 7   29      50     100     20
# 8   16     100      23     71
# 9   22      65      44     95

# %%
df1.tail(10)
# Out:
#     Age  Height  weight  speed
# 90   56      18      54     38
# 91   20      25      85     99
# 92   61      87      52     44
# 93   81      43      22     73
# 94   33      11      38     83
# 95   25      33      29     79
# 96    8      22      73     22
# 97   20      71      27     70
# 98    9      48       3     46
# 99   30      10      95     12

# %%
df1.describe()
# Out:
#               Age      Height      weight       speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    47.780000   44.810000   50.200000   55.070000
# std     30.741207   26.658974   27.522993   29.268957
# min      1.000000    0.000000    0.000000    0.000000
# 25%     20.750000   22.000000   27.000000   31.500000
# 50%     42.000000   43.000000   53.000000   54.000000
# 75%     79.250000   67.250000   70.250000   83.000000
# max     99.000000  100.000000  100.000000  100.000000

# %%
df1[['Age','Height']]
# Out:
#     Age  Height
# 0    96      45
# 1    99      21
# 2    84      32
# 3    78      76
# 4    30      33
# ..  ...     ...
# 95   25      33
# 96    8      22
# 97   20      71
# 98    9      48
# 99   30      10
#
# [100 rows x 2 columns]

# %%
df1.loc[[0,3],['Age','Height']]
# Out:
#    Age  Height
# 0   96      45
# 3   78      76

# %%
df2 = df1[['Age','Height']]

# %%
df2
# Out:
#     Age  Height
# 0    96      45
# 1    99      21
# 2    84      32
# 3    78      76
# 4    30      33
# ..  ...     ...
# 95   25      33
# 96    8      22
# 97   20      71
# 98    9      48
# 99   30      10
#
# [100 rows x 2 columns]

# %%
df2.describe()
# Out:
#               Age      Height
# count  100.000000  100.000000
# mean    47.780000   44.810000
# std     30.741207   26.658974
# min      1.000000    0.000000
# 25%     20.750000   22.000000
# 50%     42.000000   43.000000
# 75%     79.250000   67.250000
# max     99.000000  100.000000

# %%
df1.sort_index(ascending = True)
# Out:
#     Age  Height  weight  speed
# 0    96      45      76     93
# 1    99      21      27     22
# 2    84      32      64     39
# 3    78      76      55     99
# 4    30      33      21     52
# ..  ...     ...     ...    ...
# 95   25      33      29     79
# 96    8      22      73     22
# 97   20      71      27     70
# 98    9      48       3     46
# 99   30      10      95     12
#
# [100 rows x 4 columns]

# %%
df1[0::2].describe()
# Out:
#              Age      Height      weight      speed
# count  50.000000   50.000000   50.000000   50.00000
# mean   48.180000   42.260000   53.560000   53.60000
# std    32.370111   25.421998   27.289199   28.31528
# min     1.000000    0.000000    0.000000    0.00000
# 25%    19.250000   22.000000   37.250000   34.25000
# 50%    41.000000   42.000000   56.500000   49.50000
# 75%    84.000000   57.250000   72.500000   80.25000
# max    99.000000  100.000000  100.000000  100.00000

# %%
# Filter
filter1 = df1['Age'] > 50

# %%
df1[filter1]
# Out:
#     Age  Height  weight  speed
# 0    96      45      76     93
# 1    99      21      27     22
# 2    84      32      64     39
# 3    78      76      55     99
# 5    66      34       4     98
# 10   90      42      67     34
# 13   80      97      30     70
# 15   96      72      81     86
# 17   94      43      11     95
# 18   85      73      68      2
# 20   79      54      37     64
# 24   99      44      58     66
# 25   51      53      68     93
# 27   71      58      25     66
# 31   64      43      44     43
# 32   90      22      91     87
# 33   62      13      87     50
# 34   89      42      61     89
# 36   89      53      68     10
# 38   63      14      57     56
# 40   55      46      48     91
# 41   72      86      32     28
# 43   80       7      84     51
# 48   84      47      52     61
# 50   79      30      47     73
# 52   91       6      79     38
# 54   65       0      96     81
# 58   87      52      97     87
# 59   96      24      20     15
# 60   89      11      43     95
# 61   65      11      94     50
# 63   82      96      12     90
# 69   96      34      72     58
# 70   55      81      33     40
# 71   70      76       5     28
# 73   55      30      13     32
# 74   93      20      92     41
# 75   70      90      70     66
# 81   87      79      55     14
# 86   99      32       8     78
# 89   81      41      56     62
# 90   56      18      54     38
# 92   61      87      52     44
# 93   81      43      22     73

# %%
df1.loc[filter1]
# Out:
#     Age  Height  weight  speed
# 0    96      45      76     93
# 1    99      21      27     22
# 2    84      32      64     39
# 3    78      76      55     99
# 5    66      34       4     98
# 10   90      42      67     34
# 13   80      97      30     70
# 15   96      72      81     86
# 17   94      43      11     95
# 18   85      73      68      2
# 20   79      54      37     64
# 24   99      44      58     66
# 25   51      53      68     93
# 27   71      58      25     66
# 31   64      43      44     43
# 32   90      22      91     87
# 33   62      13      87     50
# 34   89      42      61     89
# 36   89      53      68     10
# 38   63      14      57     56
# 40   55      46      48     91
# 41   72      86      32     28
# 43   80       7      84     51
# 48   84      47      52     61
# 50   79      30      47     73
# 52   91       6      79     38
# 54   65       0      96     81
# 58   87      52      97     87
# 59   96      24      20     15
# 60   89      11      43     95
# 61   65      11      94     50
# 63   82      96      12     90
# 69   96      34      72     58
# 70   55      81      33     40
# 71   70      76       5     28
# 73   55      30      13     32
# 74   93      20      92     41
# 75   70      90      70     66
# 81   87      79      55     14
# 86   99      32       8     78
# 89   81      41      56     62
# 90   56      18      54     38
# 92   61      87      52     44
# 93   81      43      22     73

# %%
filter2 = df1['Age'] > 50

# %%
df1[filter1&filter2]
# Out:
#     Age  Height  weight  speed
# 0    96      45      76     93
# 1    99      21      27     22
# 2    84      32      64     39
# 3    78      76      55     99
# 5    66      34       4     98
# 10   90      42      67     34
# 13   80      97      30     70
# 15   96      72      81     86
# 17   94      43      11     95
# 18   85      73      68      2
# 20   79      54      37     64
# 24   99      44      58     66
# 25   51      53      68     93
# 27   71      58      25     66
# 31   64      43      44     43
# 32   90      22      91     87
# 33   62      13      87     50
# 34   89      42      61     89
# 36   89      53      68     10
# 38   63      14      57     56
# 40   55      46      48     91
# 41   72      86      32     28
# 43   80       7      84     51
# 48   84      47      52     61
# 50   79      30      47     73
# 52   91       6      79     38
# 54   65       0      96     81
# 58   87      52      97     87
# 59   96      24      20     15
# 60   89      11      43     95
# 61   65      11      94     50
# 63   82      96      12     90
# 69   96      34      72     58
# 70   55      81      33     40
# 71   70      76       5     28
# 73   55      30      13     32
# 74   93      20      92     41
# 75   70      90      70     66
# 81   87      79      55     14
# 86   99      32       8     78
# 89   81      41      56     62
# 90   56      18      54     38
# 92   61      87      52     44
# 93   81      43      22     73

# %%
df1.loc[filter1&filter2]
# Out:
#     Age  Height  weight  speed
# 0    96      45      76     93
# 1    99      21      27     22
# 2    84      32      64     39
# 3    78      76      55     99
# 5    66      34       4     98
# 10   90      42      67     34
# 13   80      97      30     70
# 15   96      72      81     86
# 17   94      43      11     95
# 18   85      73      68      2
# 20   79      54      37     64
# 24   99      44      58     66
# 25   51      53      68     93
# 27   71      58      25     66
# 31   64      43      44     43
# 32   90      22      91     87
# 33   62      13      87     50
# 34   89      42      61     89
# 36   89      53      68     10
# 38   63      14      57     56
# 40   55      46      48     91
# 41   72      86      32     28
# 43   80       7      84     51
# 48   84      47      52     61
# 50   79      30      47     73
# 52   91       6      79     38
# 54   65       0      96     81
# 58   87      52      97     87
# 59   96      24      20     15
# 60   89      11      43     95
# 61   65      11      94     50
# 63   82      96      12     90
# 69   96      34      72     58
# 70   55      81      33     40
# 71   70      76       5     28
# 73   55      30      13     32
# 74   93      20      92     41
# 75   70      90      70     66
# 81   87      79      55     14
# 86   99      32       8     78
# 89   81      41      56     62
# 90   56      18      54     38
# 92   61      87      52     44
# 93   81      43      22     73
