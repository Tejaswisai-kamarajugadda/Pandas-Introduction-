# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejaswisai-kamarajugadda/Pandas-Introduction-/blob/main/Working_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
#mount the drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#read file from the drive
import pandas as pd

# %%
datasetpath = '/content/retail_transactions.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv(datasetpath)

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 0      Electronics         1    150      Credit      15.0
# 1             Toys         2    317       Debit      10.0
# 2      Electronics         5    165       Debit       NaN
# 3        Furniture         6    496       Debit      10.0
# 4          Grocery        10    166       Debit       0.0
# ..             ...       ...    ...         ...       ...
# 95         Apparel         2    439        Cash      10.0
# 96     Electronics         4     52       Debit       0.0
# 97         Apparel         7    151      Credit      10.0
# 98         Apparel         5    479      Credit      10.0
# 99     Electronics         5    247      Credit      15.0
#
# [100 rows x 10 columns]

# %%
df.head(15)
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# 5           T006      2024-01-06      103        1836        515
# 6           T007      2024-01-07      103        1983        586
# 7           T008      2024-01-08      101        1806        569
# 8           T009      2024-01-09      101        1925        548
# 9           T010      2024-01-10      101        1711        565
# 10          T011      2024-01-11      103        1276        565
# 11          T012      2024-01-12      101        1486        523
# 12          T013      2024-01-13      103        1597        516
# 13          T014      2024-01-14      101        1462        520
# 14          T015      2024-01-15      104        1668        581
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 0      Electronics         1    150      Credit      15.0
# 1             Toys         2    317       Debit      10.0
# 2      Electronics         5    165       Debit       NaN
# 3        Furniture         6    496       Debit      10.0
# 4          Grocery        10    166       Debit       0.0
# 5          Grocery         9    227       Debit       NaN
# 6      Electronics         1    170      Credit       NaN
# 7             Toys         4    500       Debit       0.0
# 8          Apparel         7    217        Cash      10.0
# 9        Furniture         3    466       Debit       5.0
# 10       Furniture         1    321        Cash       NaN
# 11            Toys         8    426      Credit       5.0
# 12            Toys         5    262        Cash      15.0
# 13     Electronics        10    218        Cash       NaN
# 14            Toys         4    201       Debit      15.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    100 non-null    object
#  1   TransactionDate  100 non-null    object
#  2   StoreID          100 non-null    int64
#  3   CustomerID       100 non-null    int64
#  4   ProductID        100 non-null    int64
#  5   ProductCategory  100 non-null    object
#  6   Quantity         100 non-null    int64
#  7   Price            100 non-null    int64
#  8   PaymentType      100 non-null    object
#  9   Discount         75 non-null     float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#           StoreID   CustomerID   ProductID    Quantity      Price   Discount
# count  100.000000   100.000000  100.000000  100.000000  100.00000  75.000000
# mean   102.730000  1552.520000  554.390000    5.370000  282.15000   7.733333
# std      1.384291   268.295461   28.544098    3.013957  140.19938   5.652871
# min    101.000000  1013.000000  501.000000    1.000000   50.00000   0.000000
# 25%    101.000000  1310.250000  529.750000    3.000000  165.75000   2.500000
# 50%    103.000000  1534.000000  554.000000    5.500000  280.00000  10.000000
# 75%    104.000000  1800.750000  579.500000    8.000000  415.25000  12.500000
# max    105.000000  1983.000000  600.000000   10.000000  500.00000  15.000000

# %%
missing_values = df.isnull().sum()

# %%
print(missing_values)
# Out:
# TransactionID       0
# TransactionDate     0
# StoreID             0
# CustomerID          0
# ProductID           0
# ProductCategory     0
# Quantity            0
# Price               0
# PaymentType         0
# Discount           25
# dtype: int64

# %%
df["Quantity"] = pd.to_numeric(df["Quantity"],errors="coerce")
df["Price"] = pd.to_numeric(df["Price"],errors="coerce")
df["Discount"] = pd.to_numeric(df["Discount"],errors="coerce")

# %%
df.dtypes
# Out:
# TransactionID       object
# TransactionDate     object
# StoreID              int64
# CustomerID           int64
# ProductID            int64
# ProductCategory     object
# Quantity             int64
# Price                int64
# PaymentType         object
# Discount           float64
# dtype: object

# %%
print(df)
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 0      Electronics         1    150      Credit      15.0
# 1             Toys         2    317       Debit      10.0
# 2      Electronics         5    165       Debit       NaN
# 3        Furniture         6    496       Debit      10.0
# 4          Grocery        10    166       Debit       0.0
# ..             ...       ...    ...         ...       ...
# 95         Apparel         2    439        Cash      10.0
# 96     Electronics         4     52       Debit       0.0
# 97         Apparel         7    151      Credit      10.0
# 98         Apparel         5    479      Credit      10.0
# 99     Electronics         5    247      Credit      15.0
#
# [100 rows x 10 columns]

# %%
df['NetPrice'] = df['Price'] * (1-df['Discount'] /100)

# %%
(df)
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  NetPrice
# 0      Electronics         1    150      Credit      15.0    127.50
# 1             Toys         2    317       Debit      10.0    285.30
# 2      Electronics         5    165       Debit       NaN       NaN
# 3        Furniture         6    496       Debit      10.0    446.40
# 4          Grocery        10    166       Debit       0.0    166.00
# ..             ...       ...    ...         ...       ...       ...
# 95         Apparel         2    439        Cash      10.0    395.10
# 96     Electronics         4     52       Debit       0.0     52.00
# 97         Apparel         7    151      Credit      10.0    135.90
# 98         Apparel         5    479      Credit      10.0    431.10
# 99     Electronics         5    247      Credit      15.0    209.95
#
# [100 rows x 11 columns]

# %%
df['TotalSale'] = df['Quantity'] * df['NetPrice']

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  NetPrice  TotalSale
# 0      Electronics         1    150      Credit      15.0    127.50     127.50
# 1             Toys         2    317       Debit      10.0    285.30     570.60
# 2      Electronics         5    165       Debit       NaN       NaN        NaN
# 3        Furniture         6    496       Debit      10.0    446.40    2678.40
# 4          Grocery        10    166       Debit       0.0    166.00    1660.00
# ..             ...       ...    ...         ...       ...       ...        ...
# 95         Apparel         2    439        Cash      10.0    395.10     790.20
# 96     Electronics         4     52       Debit       0.0     52.00     208.00
# 97         Apparel         7    151      Credit      10.0    135.90     951.30
# 98         Apparel         5    479      Credit      10.0    431.10    2155.50
# 99     Electronics         5    247      Credit      15.0    209.95    1049.75
#
# [100 rows x 12 columns]

# %%
filtered_df = df[df['TotalSale'] >=20]

# %%
filtered_df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# 7           T008      2024-01-08      101        1806        569
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  NetPrice  TotalSale
# 0      Electronics         1    150      Credit      15.0    127.50     127.50
# 1             Toys         2    317       Debit      10.0    285.30     570.60
# 3        Furniture         6    496       Debit      10.0    446.40    2678.40
# 4          Grocery        10    166       Debit       0.0    166.00    1660.00
# 7             Toys         4    500       Debit       0.0    500.00    2000.00
# ..             ...       ...    ...         ...       ...       ...        ...
# 95         Apparel         2    439        Cash      10.0    395.10     790.20
# 96     Electronics         4     52       Debit       0.0     52.00     208.00
# 97         Apparel         7    151      Credit      10.0    135.90     951.30
# 98         Apparel         5    479      Credit      10.0    431.10    2155.50
# 99     Electronics         5    247      Credit      15.0    209.95    1049.75
#
# [75 rows x 12 columns]

# %%
filtered_df = df[df['TotalSale'] >=20].copy()

# %%
filtered_df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# 7           T008      2024-01-08      101        1806        569
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount  NetPrice  TotalSale
# 0      Electronics         1    150      Credit      15.0    127.50     127.50
# 1             Toys         2    317       Debit      10.0    285.30     570.60
# 3        Furniture         6    496       Debit      10.0    446.40    2678.40
# 4          Grocery        10    166       Debit       0.0    166.00    1660.00
# 7             Toys         4    500       Debit       0.0    500.00    2000.00
# ..             ...       ...    ...         ...       ...       ...        ...
# 95         Apparel         2    439        Cash      10.0    395.10     790.20
# 96     Electronics         4     52       Debit       0.0     52.00     208.00
# 97         Apparel         7    151      Credit      10.0    135.90     951.30
# 98         Apparel         5    479      Credit      10.0    431.10    2155.50
# 99     Electronics         5    247      Credit      15.0    209.95    1049.75
#
# [75 rows x 12 columns]

# %%
df.dtypes
# Out:
# TransactionID       object
# TransactionDate     object
# StoreID              int64
# CustomerID           int64
# ProductID            int64
# ProductCategory     object
# Quantity             int64
# Price                int64
# PaymentType         object
# Discount           float64
# NetPrice           float64
# TotalSale          float64
# dtype: object

# %%
if 'Payment_Type' in df.columns:
    df['Payment_Type'] = df['Payment_Type'].astype('category')

# %%
df.dtypes
# Out:
# TransactionID       object
# TransactionDate     object
# StoreID              int64
# CustomerID           int64
# ProductID            int64
# ProductCategory     object
# Quantity             int64
# Price                int64
# PaymentType         object
# Discount           float64
# NetPrice           float64
# TotalSale          float64
# dtype: object

# %%
grouped_df = df.groupby('ProductCategory').agg(
      TotalQuantity = ('Quantity','sum'),
      TotalSales = ('TotalSale','sum')
)

# %%
sorted_df = grouped_df.sort_values(by = 'TotalSales', ascending= False)

# %%
top_3_categories = sorted_df.head()

# %%
top_3_categories
# Out:
#                  TotalQuantity  TotalSales
# ProductCategory
# Toys                       137    33633.35
# Apparel                    117    25205.35
# Furniture                  130    20757.55
# Grocery                     75    14551.80
# Electronics                 78     5895.65

# %%
grouped_df = df.groupby(['StoreID','ProductCategory']).agg(
    AvgTotalSale = ('TotalSale','mean')
)

# %%
grouped_df
# Out:
#                          AvgTotalSale
# StoreID ProductCategory
# 101     Apparel           1344.550000
#         Electronics        603.375000
#         Furniture         1473.591667
#         Toys              2081.393750
# 102     Apparel           1470.300000
#         Electronics        532.975000
#         Furniture         1612.800000
#         Grocery            171.900000
#         Toys               966.980000
# 103     Apparel           1021.950000
#         Electronics               NaN
#         Furniture         1439.100000
#         Grocery            592.133333
#         Toys              1239.180000
# 104     Apparel            722.000000
#         Electronics        852.333333
#         Furniture          548.625000
#         Grocery           2365.500000
#         Toys              1367.700000
# 105     Apparel           2398.450000
#         Electronics               NaN
#         Furniture         1176.150000
#         Grocery           2047.600000
#         Toys              3216.000000

# %%
grouped_df = df.groupby(['StoreID','ProductCategory']).agg(
     AvgTotalSale= ('TotalSale','mean')
).reset_index()

# %%
top_category_df = grouped_df.loc[grouped_df.groupby('StoreID')['AvgTotalSale'].idxmax()]

# %%
top_category_df.rename(columns={'ProductCategory':'reProductCategory'}, inplace=True)

# %%
top_category_df
# Out:
#     StoreID reProductCategory  AvgTotalSale
# 3       101              Toys    2081.39375
# 6       102         Furniture    1612.80000
# 11      103         Furniture    1439.10000
# 17      104           Grocery    2365.50000
# 23      105              Toys    3216.00000
